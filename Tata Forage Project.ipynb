# %%
# -*- coding: utf-8 -*-
"""Tata_iQ_EDA_RockSolid.ipynb

100% Dependency-Free Version
"""

# Step 1: Basic Imports (No installations needed)
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Step 2: Load Data (Direct from Google Drive)
from google.colab import drive
drive.mount('/content/drive')
data = pd.read_csv('/content/Delinquency_prediction_dataset.csv')  # Update path

# Step 3: Core EDA Function
def bulletproof_eda(df):
    # 1. Basic Info
    print("🔍 BASIC INFO")
    display(df.info(verbose=True))

    # 2. Missing Data Analysis
    print("\n🧹 MISSING DATA")
    missing = df.isna().sum().to_frame('Missing Values')
    missing['% Missing'] = (missing['Missing Values']/len(df))*100
    display(missing.sort_values('% Missing', ascending=False))

    # 3. Numeric Analysis
    print("\n📊 NUMERIC STATS")
    display(df.describe().T)

    # 4. Categorical Analysis
    print("\n📌 CATEGORICAL STATS")
    cat_cols = df.select_dtypes(include=['object', 'category']).columns
    for col in cat_cols:
        print(f"\n{col}:")
        display(df[col].value_counts(normalize=True))

    # 5. Auto-Visualizations
    print("\n📈 AUTO-VISUALIZATIONS")
    numeric_cols = df.select_dtypes(include=np.number).columns
    for col in numeric_cols[:3]:  # First 3 numeric cols
        plt.figure(figsize=(10,4))
        sns.histplot(data=df, x=col, kde=True)
        plt.title(f'Distribution of {col}')
        plt.show()

    # 6. Target Analysis
    if 'Delinquent_Account' in df.columns:
        print("\n🎯 TARGET ANALYSIS")
        plt.figure(figsize=(12,5))
        for col in ['Credit_Utilization', 'Missed_Payments', 'Debt_to_Income_Ratio']:
            if col in df.columns:
                sns.boxplot(data=df, x='Delinquent_Account', y=col)
                plt.title(f'{col} vs Delinquency')
                plt.show()

# Step 4: Run Analysis
bulletproof_eda(data)

# Step 5: Save Results
data.to_csv('/content/drive/MyDrive/processed_data.csv', index=False)
print("✅ Analysis completed successfully! File saved to Google Drive.")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# 🔍 BASIC INFO
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 19 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Customer_ID           500 non-null    object
#  1   Age                   500 non-null    int64
#  2   Income                461 non-null    float64
#  3   Credit_Score          498 non-null    float64
#  4   Credit_Utilization    500 non-null    float64
#  5   Missed_Payments       500 non-null    int64
#  6   Delinquent_Account    500 non-null    int64
#  7   Loan_Balance          471 non-null    float64
#  8   Debt_to_Income_Ratio  500 non-null    float64
#  9   Employment_Status     500 non-null    object
#  10  Account_Tenure        500 non-null    int64
#  11  Credit_Card_Type      500 non-null    object
# ...
